# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import pandas_profiling as pp
import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
# 显示中文
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
# 数据加载
data=pd.read_csv('used_car_train_20200313.csv',sep=' ')
data
# Out:
#         SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  \
# 0            0     736  20040402   30.0      6       1.0       0.0      0.0
# 1            1    2262  20030301   40.0      1       2.0       0.0      0.0
# 2            2   14874  20040403  115.0     15       1.0       0.0      0.0
# 3            3   71865  19960908  109.0     10       0.0       0.0      1.0
# 4            4  111080  20120103  110.0      5       1.0       0.0      0.0
# ...        ...     ...       ...    ...    ...       ...       ...      ...
# 149995  149995  163978  20000607  121.0     10       4.0       0.0      1.0
# 149996  149996  184535  20091102  116.0     11       0.0       0.0      0.0
# 149997  149997  147587  20101003   60.0     11       1.0       1.0      0.0
# 149998  149998   45907  20060312   34.0     10       3.0       1.0      0.0
# 149999  149999  177672  19990204   19.0     28       6.0       0.0      1.0
#
# ...

# %%
# 查看数据
data.describe()
# Out:
#               SaleID           name       regDate          model  \
# count  150000.000000  150000.000000  1.500000e+05  149999.000000
# mean    74999.500000   68349.172873  2.003417e+07      47.129021
# std     43301.414527   61103.875095  5.364988e+04      49.536040
# min         0.000000       0.000000  1.991000e+07       0.000000
# 25%     37499.750000   11156.000000  1.999091e+07      10.000000
# 50%     74999.500000   51638.000000  2.003091e+07      30.000000
# 75%    112499.250000  118841.250000  2.007111e+07      66.000000
# max    149999.000000  196812.000000  2.015121e+07     247.000000
#
#                brand       bodyType       fuelType        gearbox  \
# count  150000.000000  145494.000000  141320.000000  144019.000000
# mean        8.052733       1.792369       0.375842       0.224943
# std         7.864956       1.760640       0.548677       0.417546
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# bodyType: 车身类型：豪华轿车：0，微型车：1，厢型车：2，大巴车：3，敞篷车：4，双门汽车：5，商务车：6，搅拌车：7
# fuelType: 燃油类型：汽油：0，柴油：1，液化石油气：2，天然气：3，混合动力：4，其他：5，电动：6
# gearbox: 变速箱：手动：0，自动：1

# %%
# 缺失值可视化
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
# 条形图可视化
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(data)
# Out:
# <AxesSubplot:>

# %%
# 二手车交易价格分布
plt.hist(data['price'])
plt.title('二手车交易价格分布',fontsize=15)
plt.show()

# %%
#  不同车身类型样本数据 豪华轿车：0，微型车：1，厢型车：2，大巴车：3，敞篷车：4，双门汽车：5，商务车：6，搅拌车：7
data['bodyType'].value_counts().plot(kind='bar',figsize=(15,4))
plt.title('不同车身类型的样本量',fontsize=15)
plt.show()

# %%
# 不同车型的二手车均价
data.groupby(['bodyType'])['price'].mean().plot(kind='bar',figsize=(15,4))
plt.title('不同车身类型二手车均价',fontsize=15)
plt.show()

# %%
#  gearbox: 变速箱：手动：0，自动：1
data['gearbox'].value_counts().plot(kind='bar',figsize=(15,4))
plt.title('不同变速箱的样本量',fontsize=15)
plt.show()

# %%
# 不同变速箱的二手车均价
data.groupby(['gearbox'])['price'].mean().plot(kind='bar',figsize=(15,4))
plt.title('不同变速箱类型二手车均价',fontsize=15)
plt.show()

# %%
#  不同燃油类型样本数据 汽油：0，柴油：1，液化石油气：2，天然气：3，混合动力：4，其他：5，电动：6 
data['fuelType'].value_counts().plot(kind='bar',figsize=(15,4))
plt.title('不同燃油类型的样本量',fontsize=15)
plt.show()

# %%
# 不同燃油类型的二手车均价
data.groupby(['fuelType'])['price'].mean().plot(kind='bar',figsize=(15,4))
plt.title('不同燃油类型二手车均价',fontsize=15)
plt.show()

# %%
# 对power,kilometres 进行分组
bin = [i*10 for i in range(31)]
pd.cut(data['power'],bin).value_counts().plot(kind='bar',figsize=(15,4))
plt.show()

# %%
# 行驶公里数
bin = [i*1 for i in range(10)]
pd.cut(data['kilometer'],bin).value_counts().plot(kind='bar',figsize=(15,4))
plt.show()

# %%
# 品牌
data['brand'].value_counts().plot(kind='bar',figsize=(15,4))
plt.show()

# %%
# 注册日期
data['regDate'].apply(lambda x:str(x)[:4]).value_counts().sort_index().plot(kind='bar',figsize=(15,4))
plt.show()

# %% [markdown]
# ### 单一变量结论：
# + 车身类型
#   商务车、双门汽车、敞篷车，这三种车型在市场中，二手车价格位居前三；豪华轿车交易价值较低；微型车交易价值最低
# + 变速箱
#   二手车交易市场，手动挡车居多；但自动挡的二手交易价格较高，交易均值超过手动挡二倍；
# + 燃油类型
#   二手车交易市场，以汽油、柴油为燃油的车居多；混合动力、电动、柴油为主的交易价值高于其它燃油类型的
# + 其它探索略

# %%
# pandas_profiling 一行代码生成报告
report = pp.ProfileReport(data)
report.to_file('report.html')
